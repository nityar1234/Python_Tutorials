# %%
# !pwd
# Out:
# /Users/Nitin/Python_tutorials/Day 16

# %%
pwd
# Out:
# '/Users/Nitin/Python_tutorials/Day 16'

# %% [markdown]
# Alternatively, to grab files from any location on your computer, simply pass in the entire file path.
#
# For Windows you need to use double \ so python doesn't treat the second \ as an escape character, a file path is in the form:
#
# myfile = open("C:\\Users\\YourUserName\\Home\\Folder\\myfile.txt")
#
# For MacOS and Linux you use slashes in the opposite direction:
#
# myfile = open("/Users/YouUserName/Folder/myfile.txt")

# %% [markdown]
# ### IPython Writing a File

# %%
# %%writefile test.txt
# Hello, this is a quick test file.

# %%
# %%writefile test_ns.txt
# Hello, this is a quick test file, please check.
# Out:
# Writing test_ns.txt

# %%
# !pwd
# Out:
# /Users/Nitin/Python_tutorials/Day 16

# %%
my_file = open('test_ns.txt')

# %%
# We can now read the file
my_file.read()
# Out:
# ''

# %%
# Seek to the start of file (index 0)
my_file.seek(0)
# Out:
# 0

# %%
# Open the text.txt we made earlier

my_file = open('test_v1.txt')

# %%
# We can now read the file
my_file.read()

# %%
# But what happens if we try to read it again?
my_file.read()

# %%
# Seek to the start of file (index 0)
my_file.seek(0)

# %%
# Now read again
my_file.read()

# %%
# Readlines returns a list of the lines in the file
my_file.seek(0)
my_file.readlines()

# %% [markdown]
# ### Writing to a File
# #By default, the open() function will only allow us to read the file. We need to pass the argument 'w' to write over #the file. For example:

# %%
# Add a second argument to the function, 'w' which stands for write.
# Passing 'w+' lets us read and write to the file

n_s = open('day_16_v1.txt','w+')

# %%
n_s.write('Hi, I am doing good.How about you.')
# Out:
# 34

# %%
my_file = open('day_16_v1.txt','a+')
my_file.write('\nThis is text being appended')
# Out:
# 28

# %% [markdown]
# Opening a file with 'w' or 'w+' truncates the original, meaning that anything that was in the original file is deleted!

# %%
# Write to the file

# %%
# Read the file
my_file.seek(0)
my_file.read()

# %%
my_file.close()  # always do this when you're done with a file

# %% [markdown]
# ### Appending to a File
# Passing the argument 'a' opens the file and puts the pointer at the end, so anything written is appended. Like 'w+', 'a+' lets us read and write to a file.
# If the file does not exist, one will be created.

# %%
my_file = open('ns.txt','a+')
my_file.write('\nThis is text being appended to test.txt')
my_file.write('\nAnd another line here.')

# %%
### Images

# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image

# %%
ns = Image.open('image_v1.jpeg')

# %%
pwd
# Out:
# '/Users/Nitin/Python_tutorials/Day 16'

# %%
ns
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=265x190 at 0x10126D810>

# %%
# Note this is a specialized file type from PIL (pillow)
type(python)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
# (width, height)
python.size
# Out:
# (259, 194)

# %%
python.filename
# Out:
# 'python.jpg'

# %% [markdown]
# ### Cropping Images

# %%
python.crop((0,0,250,100))
# Out:
# <PIL.Image.Image image mode=RGB size=250x100 at 0x10379F750>

# %%
### Reading Csv files

# %%
import pandas as pd

# %%
titanic_data = pd.read_csv('titanic.csv')

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Writing CSV Files with to_csv()

# %%
city = pd.DataFrame([['Sacramento', 'California'], ['Miami', 'Florida']], columns=['City', 'State'])
city.to_csv('city.csv')

# %%
city
# Out:
#          City       State
# 0  Sacramento  California
# 1       Miami     Florida
